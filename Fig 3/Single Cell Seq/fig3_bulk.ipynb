# %%
# !pip install pyreadr # required to load .rds files
# !pip install PyWGCNA # https://github.com/mortazavilab/PyWGCNA
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 364 kB 5.3 MB/s
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 49 kB 2.3 MB/s
# ...
#      |████████████████████████████████| 33.8 MB 155 kB/s
# ...
#      |████████████████████████████████| 9.7 MB 61.2 MB/s
# ...
#      |████████████████████████████████| 9.4 MB 44.3 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 54.6 MB/s
# ...
#      |████████████████████████████████| 748 kB 76.5 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 70.7 MB/s
# ...
#      |████████████████████████████████| 96 kB 4.5 MB/s
# ...
#      |████████████████████████████████| 62 kB 1.3 MB/s
# ...
#      |████████████████████████████████| 295 kB 79.5 MB/s
# ...
#      |████████████████████████████████| 965 kB 75.5 MB/s
# ...
#      |████████████████████████████████| 40 kB 4.8 MB/s
# ...

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
from pathlib import Path
import pandas as pd

DATA = Path("/content/drive/MyDrive/Genomics Project/Fig 3 Data (Alex & Onni)/Bulk RNA")

dge_file = DATA / "GSM5974202_DGE.mtx"
annot_file = DATA / "GSM5974202_cell_annotations.tsv"
meta_file = DATA / "GSM5974202_cell_annotations.csv"
genes_file = DATA / "GSM5974202_all_genes.csv"

# %%
dge = pd.read_csv(dge_file, header=0, sep=' ')
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (0,1,2,3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
pyreadr.read_r()
# Out:
#          %%MatrixMarket    matrix  coordinate  integer  general
# 0           %Rows=cells  (50104),  Cols=genes  (54232)      NaN
# 1                 50104     54232    45801982      NaN      NaN
# 2                     1         1          14      NaN      NaN
# 3                     1         8           1      NaN      NaN
# 4                     1         9          27      NaN      NaN
# ...                 ...       ...         ...      ...      ...
# 45801979          50104     43420           2      NaN      NaN
# 45801980          50104     44157           4      NaN      NaN
# 45801981          50104     44186           1      NaN      NaN
# 45801982          50104     50722           1      NaN      NaN
# 45801983          50104     54232           0      NaN      NaN
#
# [45801984 rows x 5 columns]
